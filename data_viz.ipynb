# %%
# Step 1: Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 2: Load CSV data
df = pd.read_csv("sales.csv")
print("👉 Dataset Preview:")
display(df.head())

# Step 3: Basic Statistics
print("\n👉 Summary Statistics:")
display(df.describe())

# Step 4: Plotting

# 4a. Bar Chart - Sales per Month
plt.figure(figsize=(8,5))
plt.bar(df['Month'], df['Sales'], color='skyblue')
plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# 4b. Line Plot - Sales vs Profit
plt.figure(figsize=(8,5))
plt.plot(df['Month'], df['Sales'], marker='o', label='Sales')
plt.plot(df['Month'], df['Profit'], marker='s', label='Profit')
plt.title("Sales & Profit Over Months")
plt.xlabel("Month")
plt.ylabel("Amount")
plt.legend()
plt.show()

# 4c. Histogram - Sales Distribution
plt.figure(figsize=(8,5))
plt.hist(df['Sales'], bins=5, color='lightgreen', edgecolor='black')
plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# 4d. Scatter Plot - Sales vs Profit
plt.figure(figsize=(8,5))
sns.scatterplot(x='Sales', y='Profit', data=df, s=100, color='red')
plt.title("Sales vs Profit")
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.show()
# Out:
# 👉 Dataset Preview:
#   Month  Sales  Profit
# 0   Jan  20000    5000
# 1   Feb  25000    7000
# 2   Mar  22000    6000
# 3   Apr  27000    8000
# 4   May  30000    9000
# 👉 Summary Statistics:
#               Sales       Profit
# count      6.000000     6.000000
# mean   25333.333333  7250.000000
# std     3777.124126  1541.103501
# min    20000.000000  5000.000000
# 25%    22750.000000  6250.000000
# 50%    26000.000000  7500.000000
# 75%    27750.000000  8375.000000
# max    30000.000000  9000.000000
